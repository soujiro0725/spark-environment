# %%
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from math import *

# %%
x = np.arange(-3, 3, 0.1)

# %%
print(x)
# Out:
# [-3.00000000e+00 -2.90000000e+00 -2.80000000e+00 -2.70000000e+00
#  -2.60000000e+00 -2.50000000e+00 -2.40000000e+00 -2.30000000e+00
#  -2.20000000e+00 -2.10000000e+00 -2.00000000e+00 -1.90000000e+00
#  -1.80000000e+00 -1.70000000e+00 -1.60000000e+00 -1.50000000e+00
#  -1.40000000e+00 -1.30000000e+00 -1.20000000e+00 -1.10000000e+00
#  -1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01  2.66453526e-15  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01
#   1.00000000e+00  1.10000000e+00  1.20000000e+00  1.30000000e+00
#   1.40000000e+00  1.50000000e+00  1.60000000e+00  1.70000000e+00
#   1.80000000e+00  1.90000000e+00  2.00000000e+00  2.10000000e+00
#   2.20000000e+00  2.30000000e+00  2.40000000e+00  2.50000000e+00
#   2.60000000e+00  2.70000000e+00  2.80000000e+00  2.90000000e+00]

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
y = np.sqrt(x)
# Out:
# /Users/soichi/.pyenv/versions/spark-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(x, y)

# %%
x = np.random.randn(30)

# %%
print(x)
# Out:
# [ 0.02073504 -0.69210618  0.28744293 -0.26896187  0.48304669 -0.3114622
#  -1.92511151  0.5832351  -0.99705572  1.33118089 -1.06335989  0.0923004
#  -0.45600198 -1.41598221  1.88449649  0.65968935  0.09035184 -0.73084388
#   0.21533214 -0.21589958 -0.56713203 -0.42355287  0.40275491  0.34455226
#  -0.31778871 -0.97680431  2.40713367  0.02397237 -0.02336379 -0.26844269]

# %%
y = np.sin(x) + np.random.randn(30)

# %%
plt.plot(x, y, "o")

# %%
x = np.arange(0, 10, 0.1)
y = np.sqrt(x)
plt.plot(x, y)

# %%
x = np.arange(-10, 10, 0.1)
l = 2
y = np.exp(-(x - l) ** 2)
plt.plot(x, y)

# %%
a = [[1,2], [3,3], [4,4], [5,5]]
plt.plot(*zip(*a), marker='o', color='r', ls='')

# %%
print(*zip(*a))
# Out:
# (1, 3, 4, 5) (2, 3, 4, 5)

# %%
a = [[2,0], [2,1]]
plt.plot(x, y)
plt.plot(*zip(*a), marker='o', color='r', ls='')
plt.show()
